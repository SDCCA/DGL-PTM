# %%
import osmnx as ox
import folium
import geopandas as gpd

# %%
point = (6.100635676379143, 0.12736045405150456)
radius = 3000

tags = {"amenity": ["school", "place_of_worship"]}

# tags = {"building":["religious"]}

gdf = ox.features_from_point(point, tags, dist=radius)

# %%
f = folium.Figure(width=750, height=400)
m = folium.Map(location=point, zoom_start=14).add_to(f)

for _, row in gdf.iterrows():
    folium.GeoJson(row['geometry']).add_to(m)

m
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_76ec1421d486a4115ff7080e1b29c91a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_76ec1421d486a4115ff7080e1b29c91a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_76ec1421d486a4115ff7080e1b29c91a = L.map(
#                 &quot;map_76ec1421d486a4115ff7080e1b29c91a&quot;,
#                 {
#                     center: [6.100635676379143, 0.12736045405150456],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;maxBounds&quot;: null,
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f273d40fbd1c1cbba86130b537d5de5c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f273d40fbd1c1cbba86130b537d5de5c.addTo(map_76ec1421d486a4115ff7080e1b29c91a);
#
#
#
#         function geo_json_3125063bf11ce67c39df4808cc196681_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_3125063bf11ce67c39df4808cc196681 = L.geoJson(null, {
#                 onEachFeature: geo_json_3125063bf11ce67c39df4808cc196681_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_3125063bf11ce67c39df4808cc196681_add (data) {
#             geo_json_3125063bf11ce67c39df4808cc196681
#                 .addData(data);
#         }
#             geo_json_3125063bf11ce67c39df4808cc196681_add({&quot;coordinates&quot;: [0.1387778, 6.1182064], &quot;type&quot;: &quot;Point&quot;});
#         geo_json_3125063bf11ce67c39df4808cc196681.setStyle(function(feature) {return feature.properties.style;});
#
#
#
#             geo_json_3125063bf11ce67c39df4808cc196681.addTo(map_76ec1421d486a4115ff7080e1b29c91a);
#
#
#
#         function geo_json_a769e0d4f1eeeccf4b41ed2d0e601e67_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_a769e0d4f1eeeccf4b41ed2d0e601e67 = L.geoJson(null, {
#                 onEachFeature: geo_json_a769e0d4f1eeeccf4b41ed2d0e601e67_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_a769e0d4f1eeeccf4b41ed2d0e601e67_add (data) {
#             geo_json_a769e0d4f1eeeccf4b41ed2d0e601e67
#                 .addData(data);
#         }
#             geo_json_a769e0d4f1eeeccf4b41ed2d0e601e67_add({&quot;coordinates&quot;: [0.1306741, 6.0975422], &quot;type&quot;: &quot;Point&quot;});
#         geo_json_a769e0d4f1eeeccf4b41ed2d0e601e67.setStyle(function(feature) {return feature.properties.style;});
#
#
#
#             geo_json_a769e0d4f1eeeccf4b41ed2d0e601e67.addTo(map_76ec1421d486a4115ff7080e1b29c91a);
#
#
#
#         function geo_json_4e6ecff55782ff66e37c54325a7c6a75_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_4e6ecff55782ff66e37c54325a7c6a75 = L.geoJson(null, {
#                 onEachFeature: geo_json_4e6ecff55782ff66e37c54325a7c6a75_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_4e6ecff55782ff66e37c54325a7c6a75_add (data) {
#             geo_json_4e6ecff55782ff66e37c54325a7c6a75
#                 .addData(data);
#         }
#             geo_json_4e6ecff55782ff66e37c54325a7c6a75_add({&quot;coordinates&quot;: [0.1297301, 6.0972137], &quot;type&quot;: &quot;Point&quot;});
#         geo_json_4e6ecff55782ff66e37c54325a7c6a75.setStyle(function(feature) {return feature.properties.style;});
#
#
#
#             geo_json_4e6ecff55782ff66e37c54325a7c6a75.addTo(map_76ec1421d486a4115ff7080e1b29c91a);
#
#
#
#         function geo_json_f606400fbca43a0c84c182ee7663dccc_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_f606400fbca43a0c84c182ee7663dccc = L.geoJson(null, {
#                 onEachFeature: geo_json_f606400fbca43a0c84c182ee7663dccc_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_f606400fbca43a0c84c182ee7663dccc_add (data) {
#             geo_json_f606400fbca43a0c84c182ee7663dccc
#                 .addData(data);
#         }
#             geo_json_f606400fbca43a0c84c182ee7663dccc_add({&quot;coordinates&quot;: [0.109018, 6.0930847], &quot;type&quot;: &quot;Point&quot;});
#         geo_json_f606400fbca43a0c84c182ee7663dccc.setStyle(function(feature) {return feature.properties.style;});
#
#
#
#             geo_json_f606400fbca43a0c84c182ee7663dccc.addTo(map_76ec1421d486a4115ff7080e1b29c91a);
#
#
#
#         function geo_json_4a93c000c0c1b757dce8ea367af29ee5_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_4a93c000c0c1b757dce8ea367af29ee5 = L.geoJson(null, {
#                 onEachFeature: geo_json_4a93c000c0c1b757dce8ea367af29ee5_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_4a93c000c0c1b757dce8ea367af29ee5_add (data) {
#             geo_json_4a93c000c0c1b757dce8ea367af29ee5
#                 .addData(data);
#         }
#             geo_json_4a93c000c0c1b757dce8ea367af29ee5_add({&quot;coordinates&quot;: [0.1085988, 6.0940959], &quot;typ

# %%
gdf
# Out:
#                                                               geometry  \
# element id
# node    8434198835                             POINT (0.13878 6.11821)
#         8434705003                             POINT (0.13067 6.09754)
#         8434763064                             POINT (0.12973 6.09721)
#         8434908192                             POINT (0.10902 6.09308)
#         8434915239                               POINT (0.1086 6.0941)
#         9490585505                             POINT (0.12399 6.10109)
#         9490585506                             POINT (0.12312 6.10177)
#         9490585511                             POINT (0.12822 6.10215)
#         9490585512                              POINT (0.1263 6.09719)
#         9895312327                             POINT (0.12896 6.10447)
#         9895395244                             POINT (0.13285 6.10088)
#         9895395249                             POINT (0.12739 6.09762)
#         9895395250                             POINT (0.12766 6.09855)
#         9895395256                             POINT (0.12293 6.09575)
#         9895395257                             POINT (0.12332 6.09521)
#         11141976610                             POINT (0.1138 6.09405)
# way     562714407    POLYGON ((0.12843 6.09959, 0.12849 6.09974, 0....
#         786513575    POLYGON ((0.12454 6.0978, 0.12464 6.09728, 0.1...
#         956692013    POLYGON ((0.12647 6.09741, 0.12644 6.09665, 0....
#
#                               amenity  \
# element id
# node    8434198835             school
#         8434705003             school
#         8434763064             school
#         8434908192             school
#         8434915239             school
#         9490585505             school
#         9490585506             school
#         9490585511   place_of_worship
#         9490585512   place_of_worship
#         9895312327             school
#         9895395244             school
#         9895395249   place_of_worship
#         9895395250   place_of_worship
#         9895395256   place_of_worship
#         9895395257   place_of_worship
#         11141976610  place_of_worship
# way     562714407    place_of_worship
#         786513575            hospital
#         956692013              school
#
#                                                                 name  \
# element id
# node    8434198835                          Torgorme MA Basic School
#         8434705003                                 Akuse Islamic JHS
#         8434763064                              Akuse Islamic School
#         8434908192                   VRA International School, Akuse
#         8434915239                   VRA International School, Akuse
#         9490585505                                  Akuse R/C School
#         9490585506                            Akuse Methodist School
#         9490585511            Akuse Cleland Memorial Church (Presby)
#         9490585512                     Mount Olivet Methodist Church
#         9895312327                                  Akuse Presby JHS
#         9895395244               Messiah International School, Akuse
#         9895395249                                               NaN
#         9895395250                                               NaN
#         9895395256                Pentecostal Church of Ghana, Akuse
#         9895395257             Evangelical Presbyterian Church Akuse
#         11141976610            St. Joseph the Worker Catholic Church
# way     562714407    The Church of Jesus Christ of Latter-day Saints
#         786513575                          Akuse Government Hospital
#         956692013       Akuse Methodist Senior High/Technical School
#
#                        denomination   religion service_times building  \
# element id
# node    8434198835              NaN        NaN           NaN      NaN
#         8434705003              NaN        NaN           NaN      NaN
#         8434763064              NaN        NaN           NaN      NaN
#         8434908192              NaN        NaN           NaN      NaN
#         8434915239              NaN        NaN           NaN      NaN
#         9490585505              NaN        NaN           NaN      NaN
#         9490585506              NaN        NaN           NaN      NaN
#         9490585511         catholic  christian           NaN      NaN
#         9490585512        methodist  christian           NaN      NaN
#         9895312327              NaN        NaN           NaN      NaN
#         9895395244              NaN        NaN           NaN      NaN
#         9895395249              NaN     muslim           NaN      NaN
#         9895395250              NaN     muslim           NaN      NaN
#         9895395256      pentecostal  christian           NaN      NaN
#         9895395257     presbyterian  christian           NaN      NaN
#         11141976610  roman_catholic  christian      Su 07:30      NaN
# way     562714407            mormon  christian           NaN   church
#         786513575               NaN        NaN           NaN      NaN
#         956692013         methodist  christian           NaN      NaN
#
#                     emergency healthcare healthcare:speciality  ...  \
# element id                                                      ...
# node    8434198835        NaN        NaN                   NaN  ...
#         8434705003        NaN        NaN                   NaN  ...
#         8434763064        NaN        NaN                   NaN  ...
#         8434908192        NaN        NaN                   NaN  ...
#         8434915239        NaN        NaN                   NaN  ...
#         9490585505        NaN        NaN                   NaN  ...
#         9490585506        NaN        NaN                   NaN  ...
#         9490585511        NaN        NaN                   NaN  ...
#         9490585512        NaN        NaN                   NaN  ...
#         9895312327        NaN        NaN                   NaN  ...
#         9895395244        NaN        NaN                   NaN  ...
#         9895395249        NaN        NaN                   NaN  ...
#         9895395250        NaN        NaN                   NaN  ...
#         9895395256        NaN        NaN                   NaN  ...
#         9895395257        NaN        NaN                   NaN  ...
#         11141976610       NaN        NaN                   NaN  ...
# way     562714407         NaN        NaN                   NaN  ...
#         786513575         yes   hospital               general  ...
#         956692013         NaN        NaN                   NaN  ...
#
#                     addr:place addr:region  \
# element id
# node    8434198835         NaN         NaN
#         8434705003         NaN         NaN
#         8434763064         NaN         NaN
#         8434908192         NaN         NaN
#         8434915239         NaN         NaN
#         9490585505         NaN         NaN
#         9490585506         NaN         NaN
#         9490585511         NaN         NaN
#         9490585512         NaN         NaN
#         9895312327         NaN         NaN
#         9895395244         NaN         NaN
#         9895395249         NaN         NaN
#         9895395250         NaN         NaN
#         9895395256         NaN         NaN
#         9895395257         NaN         NaN
#         11141976610        NaN         NaN
# way     562714407          NaN         NaN
#         786513575          NaN         NaN
#         956692013        Akuse     Eastern
#
#                                                            description  \
# element id
# node    8434198835                                                 NaN
#         8434705003                                                 NaN
#         8434763064                                                 NaN
#         8434908192                                                 NaN
#         8434915239                                                 NaN
#         9490585505                                                 NaN
#         9490585506                                                 NaN
#         9490585511                                                 NaN
#         9490585512                                                 NaN
#         9895312327                                                 NaN
#         9895395244                                                 NaN
#         9895395249                                                 NaN
#         9895395250                                                 NaN
#         9895395256                                                 NaN
#         9895395257                                                 NaN
#         11141976610                                                NaN
# way     562714407                                                  NaN
#         786513575                                                  NaN
#         956692013    The school was established as a co-educational...
#
#                                              email isced:level operator:short  \
# element id
# node    8434198835                             NaN         NaN            NaN
#         8434705003                             NaN         NaN            NaN
#         8434763064                             NaN         NaN            NaN
#         8434908192                             NaN         NaN            NaN
#         8434915239                             NaN         NaN            NaN
#         9490585505                             NaN         NaN            NaN
#         9490585506                             NaN         NaN            NaN
#         9490585511                             NaN         NaN            NaN
#         9490585512                             NaN         NaN            NaN
#         9895312327                             NaN         NaN            NaN
#         9895395244                             NaN         NaN            NaN
#         9895395249                             NaN         NaN            NaN
#         9895395250                             NaN         NaN            NaN
#         9895395256                             NaN         NaN            NaN
#         9895395257                             NaN         NaN            NaN
#         11141976610                            NaN         NaN            NaN
# way     562714407                              NaN         NaN            NaN
#         786513575                              NaN         NaN            NaN
#         956692013    akusemethodistshst@ges.gov.gh           3            GES
#
#                     operator:type operator:wikidata             phone  \
# element id
# node    8434198835            NaN               NaN               NaN
#         8434705003            NaN               NaN               NaN
#         8434763064            NaN               NaN               NaN
#         8434908192            NaN               NaN               NaN
#         8434915239            NaN               NaN               NaN
#         9490585505            NaN               NaN               NaN
#         9490585506            NaN               NaN               NaN
#         9490585511            NaN               NaN               NaN
#         9490585512            NaN               NaN               NaN
#         9895312327            NaN               NaN               NaN
#         9895395244            NaN               NaN               NaN
#         9895395249            NaN               NaN               NaN
#         9895395250            NaN               NaN               NaN
#         9895395256            NaN               NaN               NaN
#         9895395257            NaN               NaN               NaN
#         11141976610           NaN               NaN               NaN
# way     562714407             NaN               NaN               NaN
#         786513575             NaN               NaN               NaN
#         956692013          public         Q30263788  +233 24 451 2313
#
#                     start_date
# element id
# node    8434198835         NaN
#         8434705003         NaN
#         8434763064         NaN
#         8434908192         NaN
#         8434915239         NaN
#         9490585505         NaN
#         9490585506         NaN
#         9490585511         NaN
#         9490585512         NaN
#         9895312327         NaN
#         9895395244         NaN
#         9895395249         NaN
#         9895395250         NaN
#         9895395256         NaN
#         9895395257         NaN
#         11141976610        NaN
# way     562714407          NaN
#         786513575          NaN
#         956692013         1991
#
# [19 rows x 23 columns]
